# %%
from file import Configurator
import file

# %%
config_file_name = "paths_14032025.json"
configurator = Configurator(path_folder="/ceph/mri.meduniwien.ac.at/departments/radiology/mrsbrain/home/mschuster/Synthetic_MRSI_PhD/Synthetic_MRSI/config/",
                            file_name=config_file_name)

# %%
configurator.load()

loaded_B1_map = file.Maps(configurator=configurator, map_type_name="B1").load_file()
loaded_B1_map_shape = loaded_B1_map.loaded_maps.shape

loaded_B0_map = file.Maps(configurator=configurator, map_type_name="B0").load_file()
loaded_B0_map = loaded_B0_map.interpolate_to_target_size(target_size=loaded_B1_map_shape, order=1)


loaded_GM_map = file.Maps(configurator=configurator, map_type_name="GM_segmentation").load_file()
loaded_WM_map = file.Maps(configurator=configurator, map_type_name="WM_segmentation").load_file()
loaded_CSF_map = file.Maps(configurator=configurator, map_type_name="CSF_segmentation").load_file()


loaded_GM_map = loaded_GM_map.interpolate_to_target_size(target_size=loaded_B1_map_shape, order=1)
loaded_WM_map = loaded_WM_map.interpolate_to_target_size(target_size=loaded_B1_map_shape, order=1)
loaded_CSF_map = loaded_CSF_map.interpolate_to_target_size(target_size=loaded_B1_map_shape, order=1)
Console.printf("info", "Interpolated all maps via 'order 1' to B1 map shape")
# Out:
# [  1  ][  info   ] >> Maps object: The provided path points to a file
# [  2  ][  info   ] >> Loading nii file for map type B1
# [  3  ][ success ] ---v  (collected several lines)
#                       Loaded nii map: B1Map_TargetRes.nii | Shape: (180, 180, 109) | Values range: [-19.237, 102.543] | Unique values: 334682
#
# [  4  ][  info   ] >> Maps object: The provided path points to a file
# [  5  ][  info   ] >> Loading nii file for map type B0
# [  6  ][ success ] ---v  (collected several lines)
#                       Loaded nii map: B0Map_TargetRes.nii | Shape: (180, 180, 109) | Values range: [-533.767, 1068.09] | Unique values: 1471604
#
# [  7  ][ warning ] ---v  (automatic line breaks)
#                       !!!! DONT USE THIS METHOD ANY MORE!!!! INSTEAD INTERPOLATE VIA MAPS FROM
#                       spatial_metabolic_distribution
# [  8  ][ success ] >> Only one map exits: Interpolated map: (180, 180, 109) --> (180, 180, 109)
# [  9  ][  info   ] >> Maps object: The provided path points to a file
# [ 10  ][  info   ] >> Loading nii file for map type GM_segmentation
# [ 11  ][ success ] ---v  (collected several lines)
#                       Loaded nii map: Segmentation_GM_TargetRes_HiRes.nii | Shape: (440, 440, 266) | Values range: [0.0, 1.0] | Unique values: 5843545
#
# [ 12  ][  info   ] >> Maps object: The provided path points to a file
# [ 13  ][  info   ] >> Loading nii file for map type WM_segmentation
# [ 14  ][ success ] ---v  (collected several lines)
#                       Loaded nii map: Segmentation_WM_TargetRes_HiRes.nii | Shape: (440, 440, 266) | Values range: [0.0, 1.0] | Unique values: 3294046
#
# [ 15  ][  info   ] >> Maps object: The provided path points to a file
# [ 16  ][ warning ] ---v  (automatic line breaks)
#                       !!!! DONT USE THIS METHOD ANY MORE!!!! INSTEAD INTERPOLATE VIA MAPS FROM
#                       spatial_metabolic_distribution
# [ 17  ][ success ] >> Only one map exits: Interpolated map: (440, 440, 266) --> (180, 180, 109)
# [ 18  ][ warning ] ---v  (automatic line breaks)
#                       !!!! DONT USE THIS METHOD ANY MORE!!!! INSTEAD INTERPOLATE VIA MAPS FROM
#                       spatial_metabolic_distribution
# [ 19  ][ success ] >> Only one map exits: Interpolated map: (440, 440, 266) --> (180, 180, 109)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 17
#      15 loaded_GM_map = loaded_GM_map.interpolate_to_target_size(target_size=loaded_B1_map_shape, order=1)
#      16 loaded_WM_map = loaded_WM_map.interpolate_to_target_size(target_size=loaded_B1_map_shape, order=1)
# ---> 17 loaded_CSF_map = loaded_CSF_map.interpolate_to_target_size(target_size=loaded_B1_map_shape, order=1)
#      18 Console.printf("info", "Interpolated all maps via 'order 1' to B1 map shape")
#
# AttributeError: 'function' object has no attribute 'interpolate_to_target_size'

# %%
loaded_B0_map

# %%
type(loaded_CSF_map)
# Out:
# method
