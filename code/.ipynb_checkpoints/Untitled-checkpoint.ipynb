# %%
from spectral_spatial_simulation import LookupTableWET
from prettyconsole import Console
from file import Configurator
import file
from tools import JupyterPlotManager

# %matplotlib ipympl

# %%
config_file_name = "paths_09012026.json"
configurator = Configurator(path_folder="../config/",
                            file_name=config_file_name)
configurator.load()

# %% [markdown]
# ### Load and interpolate
#
# ### (!!!) Chosen nearest neigbour interpolation: to better sum up to 1 (GM+WM+CSF)

# %%
loaded_B1_map = file.ParameterMaps(configurator=configurator, map_type_name="B1").load_file().to_working_volume().maps[0]
target_size = loaded_B1_map.values.shape
target_gpu_interpolation = 2
loaded_B0_map = file.ParameterMaps(configurator=configurator, map_type_name="B0").load_file().to_working_volume().maps[0].interpolate(target_size=target_size, order=1, device="gpu", target_gpu=target_gpu_interpolation)
loaded_GM_map = file.ParameterMaps(configurator=configurator, map_type_name="GM_segmentation").load_file().to_working_volume().maps[0].interpolate(target_size=target_size, order=1, device="gpu", target_gpu=target_gpu_interpolation)
loaded_WM_map = file.ParameterMaps(configurator=configurator, map_type_name="WM_segmentation").load_file().to_working_volume().maps[0].interpolate(target_size=target_size, order=1, device="gpu", target_gpu=target_gpu_interpolation)
loaded_CSF_map = file.ParameterMaps(configurator=configurator, map_type_name="CSF_segmentation").load_file().to_working_volume().maps[0].interpolate(target_size=target_size, order=1, device="gpu", target_gpu=target_gpu_interpolation)
# Out:
# [ 238 ][  info   ] >> Maps object: The provided path points to a file
# [ 239 ][  error  ] >> Could not convert loaded unit 'unknown' to pint unit. Therefore, assigned 'dimensionless'!
# [ 240 ][  info   ] >> Loading nii file for map type B1
# [ 241 ][ success ] >> NaNs are not present!
# [ 242 ][ success ] ---v  (collected several lines)
#                       Loaded nii map: B1Map_TargetRes.nii | Shape: (180, 180, 109) | Values range: [-19.237, 102.543] | Unit: None | Unique values: 334682
#
# [ 243 ][ success ] ---v
#                       Created 4D volume of metabolite maps: ['B1'].
#                        Map type: ....... B1
#                        Unit: ........... None
#                        Shape: .......... (1, 180, 180, 109)
#                        Data type: ...... float64
#                        Space: .......... 26.944 mebibyte
# [ 244 ][  info   ] >> Maps object: The provided path points to a file
# [ 245 ][  info   ] >> Loading nii file for map type B0
# ...

# %% [markdown]
# ### Plot the loaded maps

# %%
JupyterPlotManager.volume_grid_viewer(
    vols=[loaded_B1_map.values, loaded_B0_map.values, loaded_GM_map.values, loaded_WM_map.values, loaded_CSF_map.values],
    titles=["B1 map", "B0 map", "GM map", "WM map", "CSF map"],
    rows=1, cols=5, cmap="viridis")

# What were this maps?
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (<Figure size 1995.79x532.105 with 21 Axes>,
#  array([[<Axes: title={'center': 'B1 map'}>,
#          <Axes: title={'center': 'B0 map'}>,
#          <Axes: title={'center': 'GM map'}>,
#          <Axes: title={'center': 'WM map'}>,
#          <Axes: title={'center': 'CSF map'}>]], dtype=object),
#  {'layout_all': <function tools.JupyterPlotManager.volume_grid_viewer.<locals>.layout_all()>,
#   'selected_panel': [0],
#   'axis_per_panel': [0, 0, 0, 0, 0],
#   'sliders': {0: <matplotlib.widgets.Slider at 0x7f291699a380>,
#    1: <matplotlib.widgets.Slider at 0x7f29169fe830>,
#    2: <matplotlib.widgets.Slider at 0x7f29168768f0>,
#    3: <matplotlib.widgets.Slider at 0x7f29168ee6e0>,
#    4: <matplotlib.widgets.Slider at 0x7f291676ad70>},
#   'images': {0: <matplotlib.image.AxesImage at 0x7f2916945cf0>,
#    1: <matplotlib.image.AxesImage at 0x7f29169c2f50>,
# ...

# %%
print(loaded_GM_map.values[91,103,60] + loaded_WM_map.values[91,103,60] + loaded_CSF_map.values[91,103,60])
print(loaded_GM_map.values[105,105,60] + loaded_WM_map.values[105,105,60] + loaded_CSF_map.values[105,105,60])
# Out:
# 0.9999999880556343
# 1.0

# %% [markdown]
# ### Check for NaNs and zeros

# %%
# TODO: Is it okay that the B1 map has only positive values and no zero values (but close to zero)? Or is zero possible?

loaded_B1_map.check_nan().enforce_positive_values(convert_negative=True, convert_zeros=True)

loaded_B0_map.check_nan()
loaded_GM_map.check_nan()
loaded_WM_map.check_nan()
loaded_CSF_map.check_nan()
# Out:
# [ 271 ][ success ] >> NaNs are not present!
# [ 272 ][ success ] >> Converted negative and zero values to eps: 2.220446049250313e-16
# [ 273 ][ success ] >> NaNs are not present!
# [ 274 ][ success ] >> NaNs are not present!
# [ 275 ][ success ] >> NaNs are not present!
# [ 276 ][ success ] >> NaNs are not present!

# %% [markdown]
# # To create the lookup table

# %%
# Fixed input variables for the Bloch Simulation
TR = 600   # [ms]
TE = 0     # [ms]
T2 = 250   # [ms]
flip_angle_excitation = 47.0           # [°] # Why exactly this flip angle?
flip_angles_WET = [89.2, 83.4, 160.8]  # [°] Why exactly this flip angles?
time_gaps_WET = [30, 30, 30]           # [ms]

# Variables containing range for generating the dictionary
T1_step_size = 50      # [ms]
T1_range = [300, 5000] # [ms]

# What is this?
B1_scales_inhomogeneity = [1e-10,3]
B1_scales_gauss = [0.01, 1]
B1_scales_inhomogeneity_step_size = 0.05
B1_scales_gauss_step_size=0.05


off_resonance=0

# To simulate the evolution of M = (Mx, My, Mz) of a spin system during a WET sequence + final excitation pulse.
lookup_table_WET_test = LookupTableWET(T1_range=T1_range,                      #### TODO: describe each of them
                                       T1_step_size=T1_step_size,
                                       T2=T2,
                                       B1_scales_inhomogeneity=B1_scales_inhomogeneity, # TODO
                                       B1_scales_gauss=B1_scales_gauss,
                                       B1_scales_inhomogeneity_step_size=B1_scales_inhomogeneity_step_size,
                                       B1_scales_gauss_step_size=B1_scales_gauss_step_size,
                                       TR=TR,
                                       TE=TE, # TODO -> why 0???
                                       flip_angle_excitation_degree=flip_angle_excitation,
                                       flip_angles_WET_degree=flip_angles_WET,
                                       time_gaps_WET=time_gaps_WET,
                                       off_resonance=off_resonance)

lookup_table_WET_test.create()
# Out:
# [ 277 ][  info   ] ---v
#                       Start creating the Lookup Table for WET (water suppression enhanced through T1 effects)
#                        => Axis 1: B1 scale | Resolution:  0.050 | Range:  0.000: 3.000
#                        => Axis 2: T1/TR    | Resolution:  0.083 | Range:  0.500: 8.333
# 100%|███████████████████████████████████████████| 95/95 [00:05<00:00, 17.81it/s]
# [ 278 ][ success ] >> Created WET lookup table with 5795 entries. Values Range: [2.8850151969148033e-05, 1.0]

# %% [markdown]
# ### To show the lookup table
#
# The $\eta$ is the attenuation:
#
# $\eta(T1, B1) = \frac{|S_{with WET}(T1, B1)|}{|S_{without WET}(T1, B1)|}$,       .....and others are const.
#
# => Everything which would be negative is red!
#
# So, when having a Signal without WET $S_{without WET}$, then $S \cdot \eta(T1, B1)$ scales this signal to incorporate the WET effects. <=== but how to make sure that it only affects the water???

# %%
lookup_table_WET_test.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# The Lookup Table shows how much transverse signal is remaining to at the redout time point.
